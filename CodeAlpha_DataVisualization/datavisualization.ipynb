# %%
# ==================================
# TASK 3: DATA VISUALIZATION
# Internship Ready Program
# ==================================

import matplotlib.pyplot as plt
import pandas as pd

# STEP 1: Create Dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May"],
    "Sales": [12000, 15000, 18000, 17000, 20000]
}

df = pd.DataFrame(data)

print("Dataset Used for Visualization:\n")
print(df)

# STEP 2: Bar Chart
plt.figure()
plt.bar(df["Month"], df["Sales"])
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Monthly Sales Analysis")
plt.show()

# STEP 3: Line Chart
plt.figure()
plt.plot(df["Month"], df["Sales"], marker='o')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Sales Trend Over Months")
plt.show()

print("\nTask 3 Data Visualization Completed Successfully ✅")
# Out:
# Dataset Used for Visualization:
#
#   Month  Sales
# 0   Jan  12000
# 1   Feb  15000
# 2   Mar  18000
# 3   Apr  17000
# 4   May  20000
# Task 3 Data Visualization Completed Successfully ✅
